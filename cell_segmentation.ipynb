# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path
import fibroblast_detection as fd
import matplotlib.pyplot as plt

# %%
in_dir = Path("./pics")
out_dir = Path("./out")

#not to change if you dont understand the code
device="cpu"

sobel_threshold = 0.1
threshold_min_radius=130
threshold_max_size=0.65
threshold_irregular=0.7


#TODO add preprocessing params them in argparser
mean_interference_value = 120 # experiemntal darkest found corresponds to blackness
min_size_noise_removal = 100 # small noise clusters that are deleted
holes_fill_iterations = 10 # higher values lead to less structured interference mask

# %%
images = fd.load_folder_images(in_dir,sobel_threshold)
print(images)
# Out:
# [<fibroblast_images.ImageFibroblast object at 0x77780e3b2900>, <fibroblast_images.ImageFibroblast object at 0x77780c1b7390>, <fibroblast_images.ImageFibroblast object at 0x7776b57b5310>, <fibroblast_images.ImageFibroblast object at 0x77780c2e0d60>, <fibroblast_images.ImageFibroblast object at 0x77780c1cdf30>, <fibroblast_images.ImageFibroblast object at 0x7777b874c170>, <fibroblast_images.ImageFibroblast object at 0x7776acb57ac0>, <fibroblast_images.ImageFibroblast object at 0x7776acb57bd0>, <fibroblast_images.ImageFibroblast object at 0x7777b872a250>, <fibroblast_images.ImageFibroblast object at 0x7776b5785d50>, <fibroblast_images.ImageFibroblast object at 0x77780e407d40>, <fibroblast_images.ImageFibroblast object at 0x77780e407c50>]

# %%
fd.preprocess_images(images)
# Out:
# (1211, 1600, 3)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 fd.preprocess_images(images)
#
# File ~/Documents/Hobby/fibroblast_detection/fibroblast_detection.py:37, in preprocess_images(images)
#      35 def preprocess_images(images:List[ImageFibroblast]):
#      36     for image in images:
# ---> 37         image.preprocess_images()
#
# File ~/Documents/Hobby/fibroblast_detection/fibroblast_images.py:92, in ImageFibroblast.preprocess_images(self)
#      90 self.kmeans_labels = self.kmeans(self.image)
#      91 if self.is_interference():
# ---> 92     self.impute_values()
#
# File ~/Documents/Hobby/fibroblast_detection/fibroblast_images.py:86, in ImageFibroblast.impute_values(self)
#      84 mask = self.kmeans_labels==0
#      85 cleaned_mask = self.create_cleaned_mask(mask)
# ---> 86 self.image = self.remove_with_polyfit(self.original_image,cleaned_mask,rng=np.random.default_rng(13))
#
# File ~/Documents/Hobby/fibroblast_detection/fibroblast_images.py:5, in remove_with_polyfit(bg, mask, degree, add_noise, rng)
#       3 import numpy as np
#       4 import matplotlib.pyplot as plt
# ----> 5 from skimage.filters import sobel
#       6 from sklearn.cluster import MiniBatchKMeans
#       7 from sklearn.preprocessing import PolynomialFeatures
#
# ValueError: too many values to unpack (expected 2)

# %%
model = fd.load_model(device)

# %%
fd.start_detect_in_images(images,model)

# %%
[image.plot_preprocessing(save_dir=out_dir) for image in images]
[image.plot_threshold_histogram(save_dir=out_dir) for image in images]
[image.plot_segmentation_masks for image in images]
[image.plot_cell_with_edges(save_dir=out_dir) for image in images]
[image.plot_cell_areas(saver_dir=out_dir) for image in images]

# %%
ratios = fd.get_ratios(images,out_dir=out_dir)
areas  = fd.get_pixels_area(images,out_dir=out_dir)
fd.combine_ratios_areas(ratios,areas,out_dir=out_dir)
